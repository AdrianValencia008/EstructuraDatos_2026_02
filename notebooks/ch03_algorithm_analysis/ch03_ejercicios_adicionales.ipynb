# %% [markdown]
#  The number of operations executed by algorithms A and B is $8n\log n$ and
# $2n^2$, respectively. Determine n0 such that A is better than B for $n ≥ n_0$.

# %%
# 3.45
import random
n = 700
l = random.randint(0,699)
S = [i for i in range(0,n) if i != l]

# %%
def encontrar(S):
    '''Encuentra el entero que falta entre 0 y len(S)+1'''
    o = 0
    for i in range(len(S)+1):
        for h in S:
            if i == h:

# %%
def encontrar1(S):
    suma = 0
    for i in S:
        suma += i
    n = len(S)
    return (n)*(n+1)/2 - suma

# %%
encontrar1(S), encontrar1([3,0,1])
# Out:
# (171.0, 2.0)
